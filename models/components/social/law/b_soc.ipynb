# %%
import ipywidgets as widgets
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import ipywidgets as widgets
#
# ModuleNotFoundError: No module named 'ipywidgets'

# %% [markdown]
# ## Read data

# %%
file_name = './b_soc_obj.json'

with open(file_name,encoding='utf8') as fp:
    data_organ_sickness = json.load(fp)
# initial
num_object = 5
objects = [cobject() for i in range(1,num_object)]
objects[0].name = "worker"
objects[1].name = "manager"
objects[2].name = "lord"
objects[3].name = "king"
print(objects[0].name)
print("test world ok")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 file_name = './b_soc_obj.json'
#       3 with open(file_name,encoding='utf8') as fp:
# ----> 4     data_organ_sickness = json.load(fp)
#       5 # initial
#       6 num_object = 5
#
# NameError: name 'json' is not defined

# %%
class cobject:
    def __init__(self):
        # property
        self.name = ""
        self.money = 1
        self.relation = ["tax", "friend"]
        self.price = [4, 10]
        self.real = [1, 1]
        self.will = [0.1, 0.2]
        self.push = [1, 0.1]
        # rule
        self.exchange = 1
        self.tax = 1
        self.law = 1
        self.force = 1
        # optimize
        #self.equ_opt = self.money + self.price[0]*max(self.will[0],self.push[0]) + self.price[1]*max(self.will[1],self.push[1])
        # update
        self.update()
    def update(self):
        self.a = 1
    __update = update
cobj = cobject()
